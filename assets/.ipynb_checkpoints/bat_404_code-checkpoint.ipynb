# %% [markdown]
# <h2>Importing Libraries</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mpl
import seaborn as sns
import os

from array import array
from scipy.stats import skew

# %% [markdown]
# <h2>Importing Datasets</h2>

# %%
# Datasets of India
ind_agriPrac = 'Datasets/ind_AgriculturalPracticesDatasets_verified.csv'
ind_clmtWthr = 'Datasets/ind_mean_temperature_verified.csv'

# General with no country as specific focus
gen_popltion = 'Datasets/ind_population.csv'
gen_rainfall = 'Datasets/rainfall_dataset.csv'
gen_waterAva = 'Datasets/water_availability_datasets.csv'

read_dset = pd.read_csv('Datasets/agricultural_lands_dataset.csv')
rdfl_dset = pd.read_csv('Datasets/forest_lands_datasets.csv')

# Datasets of Philippines
phi_agriPrac = 'Datasets/phi_AgriculturalPracticesDatasets_verified.csv'
phi_clmtWthr = 'Datasets/phi_mean_temperature_verified.csv'

# %% [markdown]
# <h2>Reading Datasets</h2>

# %%
# India
in_rd_agriPr = ind_agriPrac
in_rd_clmtWt = ind_clmtWthr

# General
gn_rd_popltn = gen_popltion
gn_rd_rainfl = gen_rainfall
gn_rd_wtrAvl = gen_waterAva
gn_rd_forLnd = rdfl_dset

# Philippines
ph_rd_agriPr = phi_agriPrac
ph_rd_clmtWt = phi_clmtWthr

# %% [markdown]
# <h2>Data Cleaning with Data Visualizations</h2>

# %%
dFIndAgriPrc = pd.read_csv(in_rd_agriPr)
dFIndAgriPrc.head()
# Out:
#                         State District       Crop  Crop_Year       Season  \
# 0  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Kharif
# 1  Andaman and Nicobar Island  NICOBARS  Arecanut       2007  Rabi
# 2  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Autumn
# 3  Andaman and Nicobar Island  NICOBARS  Arecanut       2008  Summer
# 4  Andaman and Nicobar Island  NICOBARS  Arecanut       2009  Autumn
#
#     Area   Production  Yield
# 0  2439.6      3415.0   1.40
# 1  1626.4      2277.0   1.40
# 2  4147.0      3060.0   0.74
# 3  4147.0      2660.0   0.64
# 4  4153.0      3120.0   0.75

# %%
dFIndPpltion = pd.read_csv(gn_rd_popltn)
dFIndPpltion.head()
# Out:
#          Data Source World Development Indicators         Unnamed: 2  \
# 0                NaN                          NaN                NaN
# 1  Last Updated Date                   10/05/2023                NaN
# 2                NaN                          NaN                NaN
# 3       Country Name                 Country Code     Indicator Name
# 4              Aruba                          ABW  Population, total
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3  Indicator Code      1960.0      1961.0      1962.0      1963.0      1964.0
# 4     SP.POP.TOTL     54608.0     55811.0     56682.0     57475.0     58178.0
#
#    Unnamed: 9  ...  Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  \
# ...

# %%
# Dropping the first four empty rows
dFIndPpltion = dFIndPpltion.drop(index = dFIndPpltion.index[:4])

# Renaming Header using for loop
arrHeader_01 = [
    'Data Source', 'World Development Indicators', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964'
    , '1965', '1966', '1967', '1968', '1968', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979'
    , '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994'
    , '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009'
    , '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'
]

for index, arrValue in enumerate(dFIndPpltion.columns):
    dFIndPpltion = dFIndPpltion.rename(columns = {arrValue: arrHeader_01[index]})

# Dropping rows
dFIndPpltion = dFIndPpltion[(dFIndPpltion['Data Source'] == 'India') | (dFIndPpltion['Data Source'] == 'Philippines')]
cl_to_remove = ['Data Source', 'World Development Indicators', 'Indicator Name', 'Indicator Code']
new_dFIndPpl = dFIndPpltion.drop(columns = cl_to_remove)
new_dFIndPpl = new_dFIndPpl.iloc[:, :-1]
new_dFIndPpl = new_dFIndPpl.reset_index(drop=True)

new_dFIndPpl.head()
# Out:
#           1960         1961         1962         1963         1964  \
# 0  445954579.0  456351876.0  467024193.0  477933619.0  489059309.0
# 1   28486871.0   29342411.0   30185979.0   31043711.0   31916622.0
#
#           1965         1966         1967         1968         1968  ...  \
# 0  500114346.0  510992617.0  521987069.0  533431909.0  545314670.0  ...
# 1   32805538.0   33704749.0   34616857.0   35544973.0   36477170.0  ...
#
#            2012          2013          2014          2015          2016  \
# 0  1.274487e+09  1.291132e+09  1.307247e+09  1.322867e+09  1.338636e+09
# 1  9.803232e+07  9.970011e+07  1.013252e+08  1.030314e+08  1.048753e+08
#
#            2017          2018          2019          2020          2021
# 0  1.354196e+09  1.369003e+09  1.383112e+09  1.396387e+09  1.407564e+09
# 1  1.067385e+08  1.085688e+08  1.103808e+08  1.121910e+08  1.138803e+08
#
# [2 rows x 62 columns]

# %%
ind_yrMentnd = dFIndAgriPrc['Crop_Year'].sort_values().unique()

ind_prodArry = array('f', [])
ind_popuArry = array('f', [])
ind_dateArry = array('i', [])
ind_normProd = array('f', [])

ind_emptDict = {}

for ln50_idx, ln50_val in dFIndAgriPrc['Production'].items():
    if ln50_val == None:
        dFIndAgriPrc.at[index, 'Production'] = 0

for ln51_val in ind_yrMentnd:
    ind_dateArry.append(ln51_val)
    in_prodTbl = dFIndAgriPrc.loc[dFIndAgriPrc['Crop_Year'] == ln51_val, 'Production'].sum()
    ind_prodArry.append(in_prodTbl)
    

for ln52_val in new_dFIndPpl.columns:
    column_data = new_dFIndPpl[ln52_val].iloc[0]
    ind_emptDict[ln52_val] = column_data


for key, value in ind_emptDict.items():
    int_key = int(key)
    
    if int_key in ind_dateArry:
        ind_popuArry.append(value)

ln53_idx = 0
for ln53_val in ind_dateArry:
    ln53_idx += 1
    
    nw_prdctn = ind_prodArry[ln53_idx - 1]
    nw_popltn = ind_popuArry[ln53_idx - 1]
    normalizd = nw_popltn/nw_prdctn
    
    
    if normalizd >= 10:
        ind_normProd.append(0.15)
    else:
        frmt_nrml = format(normalizd, ".2f")
        ind_normProd.append(float(frmt_nrml))

# %%
dFPhiAgriPrc = pd.read_csv(ph_rd_agriPr)
tempHolder_v = 0
phi_emptDict = {}
phi_emptDct1 = {}

phi_normProd = array('f', [])
phi_popuArry = array('f', [])
phi_prodArry = array('f', [])

# Dropping the first two columns
dFPhiAgriPrc = dFPhiAgriPrc.iloc[:, 2:]

for ln53_idx, ln53_val in enumerate(dFPhiAgriPrc.columns):
    for ln54_idx, ln54_val in dFPhiAgriPrc[ln53_val].items():
        if ln54_val == '..':
            data = dFPhiAgriPrc.at[ln54_idx, ln53_val] = 0

            
for ln55_idx, ln55_val in enumerate(dFPhiAgriPrc.columns):
    for ln56_idx, ln56_val in dFPhiAgriPrc[ln53_val].items():
        tempHolder_v += ln56_val
    phi_emptDict[ln55_val] = tempHolder_v

    
for ln56_val in new_dFIndPpl.columns:
    column_data = new_dFIndPpl[ln56_val].iloc[1]
    phi_emptDct1[ln56_val] = column_data
    
    
for ky1, ln57_val in phi_emptDct1.items():
    int_ky1 = int(ky1)
    
    if int_ky1 in ind_dateArry:
        phi_popuArry.append(ln57_val)

        
for ky2, ln59_val in phi_emptDict.items():
    int_ky2 = int(ky2)
    
    if int_ky2 in ind_dateArry:
        phi_prodArry.append(ln59_val)
        
        
ln58_idx = 0
for ln58_val in ind_dateArry:
    ln58_idx += 1
    
    nw_prdctn = phi_prodArry[ln58_idx - 1]
    nw_popltn = phi_popuArry[ln58_idx - 1]
    normalizd = nw_popltn/nw_prdctn
    
    frmt_nrml = format(normalizd, ".2f")
    phi_normProd.append(float(frmt_nrml))

# %%
# Calculate skewness for each country
skewness_india = skew(phi_normProd)
skewness_philippines = skew(ind_normProd)

# Print the skewness values
print("Skewness for India: {:.2f}".format(skewness_india))
print("Skewness for Philippines: {:.2f}".format(skewness_philippines))
# Out:
# Skewness for India: 0.86
# Skewness for Philippines: 1.25

# %%
mpl.figure(figsize=(11, 3))
mpl.subplot(1, 2, 1)

# Plot histogram with density curve
sns.histplot(phi_normProd, kde=True)

# Add labels and title
mpl.xlabel('Values')
mpl.ylabel('Density')
mpl.title('Agricultural Skewness: \nRice Production in Philippines', fontsize=10, pad=20)


mpl.subplot(1, 2, 2)

# Plot histogram with density curve
sns.histplot(ind_normProd, kde=True, color='orange')

# Add labels and title
mpl.xlabel('Values')
mpl.ylabel('Density')
mpl.title('Agricultural Skewness: \nRice Production in India', fontsize=10, pad=20)


# Show the plot
mpl.show()

# %%
dFPhiAgriPrc = pd.read_csv(ph_rd_agriPr)
dFIndPpltion = pd.read_csv(gn_rd_popltn)
arr_ln61_val = array('i', [])
arr_for_labl = []
arr_for_data = array('f', [])


state_number = dFPhiAgriPrc['Provinces'].unique()

new_phiAPrac = dFPhiAgriPrc.iloc[:, 1:]

for ln61_val in enumerate(new_phiAPrac.columns):
    if ln61_val[1] != 'Provinces':
        new_ln61_val = int(ln61_val[1])
        arr_ln61_val.append(new_ln61_val)
    
for state_val in state_number:
    keyword = state_val

    # Filter the DataFrame based on the keyword
    filtered_df = new_phiAPrac[new_phiAPrac['Provinces'] == keyword]
    
    # Get the sum horizontally across the matching rows
    sum_result = filtered_df.iloc[:, 1:].sum(axis=1)
    total_sum = sum_result.sum()

    # Print the total sum
    frmt_sumv = format(total_sum, ".2f")
    arr_for_labl.append(state_val)
    arr_for_data.append(float(frmt_sumv))

# %%
dFPhiWeather = pd.read_csv(ph_rd_clmtWt)
dFIndWeather = pd.read_csv(in_rd_clmtWt)

dta_phi_wthr = array('f', [])
dta_ind_wthr = array('f', [])
lbl_ind_wthr = []

# Declare the year for weather datasets
wthr_year = dFIndWeather['YEAR'].sort_values().unique()

# Renaming Header using for loop
arrHeader_02 = ['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']

for arrH02_idx, arrH02_val in enumerate(dFPhiWeather.columns):
    dFPhiWeather = dFPhiWeather.rename(columns = {arrH02_val: arrHeader_02[arrH02_idx]})
    
    
for ph_new_wthr in wthr_year:
    keyword = ph_new_wthr

    # Filter the DataFrame based on the keyword
    filtered_df = dFPhiWeather[dFPhiWeather['YEAR'] == keyword]
    
    # Get the sum horizontally across the matching rows
    sum_result = filtered_df.iloc[:, 1:].mean(axis=1)
    total_sum = sum_result.mean()

    frmt_sumv = format(total_sum, ".2f")
    dta_phi_wthr.append(float(frmt_sumv))


for in_new_wthr in wthr_year:
    keyword = in_new_wthr

    # Filter the DataFrame based on the keyword
    filtered_df = dFIndWeather[dFIndWeather['YEAR'] == keyword]
    
    # Get the sum horizontally across the matching rows
    sum_result = filtered_df.iloc[:, 1:].mean(axis=1)
    total_sum = sum_result.mean()
    
    frmt_sumv = format(total_sum, '.2f')
    lbl_ind_wthr.append(in_new_wthr)
    dta_ind_wthr.append(float(frmt_sumv))

# %%
nw_rainfllDt = pd.read_csv(gn_rd_rainfl)
nw_rainfllDt = nw_rainfllDt[(nw_rainfllDt['Country Name'] == 'India') | (nw_rainfllDt['Country Name'] == 'Philippines')]

idx_dmp_data = array('i', [])
phi_rainData = array('i', [0])
ind_rainData = array('i', [0])
yrs_rainData = [1989]

# Dropping columns that is unneccessary or does not contain any usable data.
rainlbls_drp = ['Country Name', '2021', '2022']
nw_rainfllDt = nw_rainfllDt.drop(labels=rainlbls_drp, axis=1)

for rain_index, rain_value in enumerate(nw_rainfllDt.columns):
    yrs_rainData.append(int(rain_value))
    for rain_items in nw_rainfllDt[rain_value].items():
        if rain_index in idx_dmp_data:
            phi_rainData.append(int(rain_items[1]))
        else:
            ind_rainData.append(int(rain_items[1]))
            idx_dmp_data.append(rain_index)

# %%
nw_rainfllDt = pd.read_csv(gn_rd_rainfl)
nw_rainfllDt.head()
# Out:
#                   Country Name    1990    1991    1992    1993    1994  \
# 0                        Aruba     NaN     NaN     NaN     NaN     NaN
# 1  Africa Eastern and Southern     NaN     NaN     NaN     NaN     NaN
# 2                  Afghanistan   327.0   327.0   327.0   327.0   327.0
# 3   Africa Western and Central     NaN     NaN     NaN     NaN     NaN
# 4                       Angola  1010.0  1010.0  1010.0  1010.0  1010.0
#
#      1995    1996    1997    1998  ...    2013    2014    2015    2016  \
# 0     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 2   327.0   327.0   327.0   327.0  ...   327.0   327.0   327.0   327.0
# 3     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN
# 4  1010.0  1010.0  1010.0  1010.0  ...  1010.0  1010.0  1010.0  1010.0
#
#      2017    2018    2019    2020  2021  2022
# 0     NaN     NaN     NaN     NaN   NaN   NaN
# ...

# %%
nw_rainfllDt = nw_rainfllDt[(nw_rainfllDt['Country Name'] == 'India') | (nw_rainfllDt['Country Name'] == 'Philippines')]

idx_dmp_data = array('i', [])
phi_rainData = array('i', [0])
ind_rainData = array('i', [0])
yrs_rainData = [1989]

# Dropping columns that is unneccessary or does not contain any usable data.
rainlbls_drp = ['Country Name', '2021', '2022']
nw_rainfllDt = nw_rainfllDt.drop(labels=rainlbls_drp, axis=1)

for rain_index, rain_value in enumerate(nw_rainfllDt.columns):
    yrs_rainData.append(int(rain_value))
    for rain_items in nw_rainfllDt[rain_value].items():
        if rain_index in idx_dmp_data:
            phi_rainData.append(int(rain_items[1]))
        else:
            ind_rainData.append(int(rain_items[1]))
            idx_dmp_data.append(rain_index)

# %%
nw_rainfllDt.head()
# Out:
#        1990    1991    1992    1993    1994    1995    1996    1997    1998  \
# 109  1123.0  1172.0  1179.0  1164.0  1167.0  1132.0  1149.0  1191.0  1194.0
# 187  2316.0  2214.0  2387.0  2156.0  2265.0  2432.0  2281.0  2355.0  2165.0
#
#        1999  ...    2011    2012    2013    2014    2015    2016    2017  \
# 109  1126.0  ...  1105.0  1137.0  1165.0  1175.0  1127.0  1169.0  1185.0
# 187  2307.0  ...  2437.0  2167.0  2309.0  2252.0  2375.0  2114.0  2449.0
#
#        2018    2019    2020
# 109  1160.0  1114.0  1182.0
# 187  2203.0  2331.0  2285.0
#
# [2 rows x 31 columns]

# %%
# Rainfall Line Chart
mpl.figure(figsize=(10.8, 3))
mpl.subplot(1, 2, 1)
mpl.plot(yrs_rainData, phi_rainData, label='Philippines Data')
mpl.plot(yrs_rainData, ind_rainData, label='India Data')

mpl.xlabel('Year')
mpl.ylabel('Rainfall in mm')
mpl.legend()

mpl.title('Rainfall Patterns Revealed: \nContrasting India and the Philippines', fontsize=10, pad=20)


#displaying results
mpl.subplot(1, 2, 2)
mpl.subplots_adjust(wspace=0.5)

mpl.plot(wthr_year, dta_phi_wthr, label='Philippines Data')
mpl.plot(wthr_year, dta_ind_wthr, label='India Data')

mpl.xlabel('Year')
mpl.ylabel('Mean Temperature')

mpl.title('Comparative Analysis of Mean Temperature: \nExploring Philippines and India', fontsize=10, pad=20)
mpl.legend()

mpl.show()

# %%
read_dset.head()
# Out:
#                   Country Name       1961       1962       1963       1964  \
# 0                        Aruba  11.111111  11.111111  11.111111  11.111111
# 1  Africa Eastern and Southern  42.345505  42.329995  42.366298  42.348112
# 2                  Afghanistan  57.801696  57.893688  57.970348  58.066940
# 3   Africa Western and Central  32.945755  33.061986  33.318095  33.446227
# 4                       Angola  36.237443  36.261506  36.277549  36.301612
#
#         1965       1966       1967       1968       1969  ...       2011  \
# 0  11.111111  11.111111  11.111111  11.111111  11.111111  ...  11.111111
# 1  42.330887  42.356965  42.370485  42.403700  42.454346  ...  46.361515
# 2  58.070006  58.128268  58.229459  58.230992  58.255523  ...  58.123668
# 3  33.712301  33.693993  33.664741  33.764787  34.388568  ...  39.105860
# 4  36.317655  36.341718  36.365782  36.389845  36.421930  ...  42.566024
#
#         2012       2013       2014       2015       2016       2017  \
# ...

# %%
read_dset = read_dset[(read_dset['Country Name'] == 'India') | (read_dset['Country Name'] == 'Philippines')]

read_dump = array('i', [])
read_phDt = array('f', [])
read_inDt = array('f', [])
read_year = array('i', [])

# Dropping columns that is unneccessary or does not contain any usable data.
drp_landD = ['Country Name', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972'
                , '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986'
                , '1987', '1988', '1989', '1990']

read_dset = read_dset.drop(labels=drp_landD, axis=1)

for land_index, land_value in enumerate(read_dset.columns):
    read_year.append(int(land_value))
    for land_items in read_dset[land_value].items():
        if land_index in read_dump:
            read_phDt.append(float(land_items[1]))
        else:
            read_inDt.append(float(land_items[1]))
            read_dump.append(land_index)

# %%
rdfl_dset.head()
# Out:
#                   Country Name       1990       1991       1992       1993  \
# 0                        Aruba   2.333333   2.333333   2.333333   2.333333
# 1  Africa Eastern and Southern  36.230006  36.078752  35.927499  35.776246
# 2                  Afghanistan   1.852782   1.852782   1.852782   1.852782
# 3   Africa Western and Central  22.776908  22.658746  22.540583  22.422421
# 4                       Angola  63.578070  63.453407  63.328745  63.204082
#
#         1994       1995       1996       1997       1998  ...       2013  \
# 0   2.333333   2.333333   2.333333   2.333333   2.333333  ...   2.333333
# 1  35.624993  35.473739  35.322486  35.171233  35.019980  ...  31.680565
# 2   1.852782   1.852782   1.852782   1.852782   1.852782  ...   1.852782
# 3  22.304258  22.186096  22.067933  21.949771  21.831608  ...  20.410143
# 4  63.079419  62.954757  62.830094  62.705431  62.580768  ...  56.543526
#
#         2014       2015       2016       2017       2018       2019  \
# ...

# %%
rdfl_dset = rdfl_dset[(rdfl_dset['Country Name'] == 'India') | (rdfl_dset['Country Name'] == 'Philippines')]

rdfl_dump = array('i', [])
rdfl_phDt = array('f', [])
rdfl_inDt = array('f', [])
rdfl_year = array('i', [])

# Dropping columns that is unneccessary or does not contain any usable data.
drp_forLn = ['Country Name', '2021', '2022']

rdfl_dset = rdfl_dset.drop(labels=drp_forLn, axis=1)

for frst_index, frst_value in enumerate(rdfl_dset.columns):
    rdfl_year.append(int(frst_value))
    for frst_items in rdfl_dset[frst_value].items():
        if frst_index in rdfl_dump:
            rdfl_phDt.append(float(frst_items[1]))
        else:
            rdfl_inDt.append(float(frst_items[1]))
            rdfl_dump.append(frst_index)

# %%
mpl.figure(figsize=(10.8, 4))
mpl.bar(read_year, read_inDt, width=0.5, label='India', color='orange')
mpl.bar(read_year, read_phDt, width=0.5, label='Philippines')

# Add labels and title
mpl.xlabel('Year')
mpl.ylabel('Agrigultural Lands in Percentage', labelpad=20)
mpl.title('Comparative Analysis of Agricultural Land Distribution: \n India vs. Philippines in Percentage', fontsize=10, pad=20)

# Add legend
mpl.legend()


# Lands Chart
mpl.figure(figsize=(11, 3))
mpl.subplot(1, 2, 1)
mpl.bar(rdfl_year, rdfl_inDt, width=0.5, label='India', color='orange')

# Add labels and title
mpl.xlabel('Year')
mpl.ylabel('Forest Lands in Percentage', labelpad=10)
mpl.title('India Available Forest Lands in percentage', fontsize=10, pad=20)


#displaying results
mpl.subplot(1, 2, 2)
mpl.subplots_adjust(wspace=0.3)

mpl.bar(rdfl_year, rdfl_phDt, width=0.5, label='Philippines')

# Add labels and title
mpl.xlabel('Year')
mpl.ylabel('Forest Lands in Percentage', labelpad=10)
mpl.title('Philippines Available Forest Lands in percentage', fontsize=10, pad=20)

mpl.show()

# %%
#displaying results
mpl.figure(figsize=(11, 6))

mpl.plot(ind_dateArry, phi_normProd, label='Philippines Data')
mpl.plot(ind_dateArry, ind_normProd, label='India Data')

mpl.xlabel('Year')
mpl.ylabel('Production')

mpl.title('Philippines and India Comparative Analysis about rice production')

mpl.xticks(ind_dateArry)
mpl.xticks(rotation=45)

mpl.legend()
mpl.show()

# %%
mpl.figure(figsize=(9.2, 14))

# Create the horizontal bar chart
mpl.barh(arr_for_labl, arr_for_data)


# Add labels and title
mpl.xlabel('Values')
mpl.ylabel('Provinces')
mpl.title('Horizontal Bar Chart For Produced Rice In Each Provinces')

# Adjust spacing between y-axis labels
mpl.tick_params(axis='y', labelsize=7)

# Show the chart
mpl.show()

# %% [markdown]
# <h2>Results</h2>
#
# <h3>Notable Findings</h3>
# The following entails the notable findings from the study based on graphs:
# <ol>
#     <li>Philippines Rice Production is positively skewed.</li>
#     <li>As time passes by, the normalized value of rice production is decreasing.</li>
#     <li>The average annual rainfall in mm of Philippines is higher compared to India's 1000 - 1500 mm.</li>
#     <li>The Philippines has a higher mean temperature compared to India, not until 2020.</li>
#     <li>Philippines agricultural land is slightly increasing.</li>
#     <li>Philippiines available forest land is decreasing as time passes by, not until 2010 where changes occur in a positive manner.</li>
# </ol>
#
#
#
# <h3>Conclusion.</h3>
# Based on the findings, here are the conclusions that the students were able to draw:
#
# <ol>
#     <li><b>Positive Skewness in Philippines Rice Production:</b> The positive skewness indicates that the majority of rice production values are concentrated towards the lower end, with a few higher values that pull the average upward. This suggests that there might be a few regions or factors contributing significantly to rice production in the Philippines.</li>
#     <li><b>Decreasing Normalized Rice Production:</b> The decreasing trend in normalized rice production over time suggests that the relative rice production values have been decreasing. This could be due to various factors such as changes in agricultural practices, environmental factors, population growth, or shifts in the economy.</li>
#     <li><b>Higher Average Rainfall in the Philippines compared to India:</b> The average annual rainfall in the Philippines is higher compared to the range of 1000-1500 mm in India. This implies that the Philippines generally receives more precipitation, which can have implications for agriculture and water resource management.</li>
#     <li><b>Higher Mean Temperature in the Philippines compared to India (until 2020):</b> The Philippines has a higher mean temperature compared to India, indicating that the climate in the Philippines tends to be warmer on average. However, it is important to note the mention of "until 2020," suggesting that the trend might have changed after that year.</li>
#     <li><b>Slight Increase in Agricultural Land in the Philippines:</b> The slight increase in agricultural land in the Philippines indicates a potential expansion or utilization of land for agricultural purposes. This could be driven by factors such as population growth, changes in land use policies, or agricultural development initiatives.</li>
#     <li><b>Decrease in Available Forest Land in the Philippines (until 2010):</b> The decreasing trend in available forest land in the Philippines suggests a decline in the total area of forests. This could be a concerning trend as it may indicate deforestation or changes in land use patterns, which can have negative environmental impacts such as habitat loss and reduced biodiversity.</li>
# </ol>
#
# In general, it's clear that the Philippines has favorable conditions with sufficient rainfall and suitable temperatures for growing crops like rice. However, it's puzzling why the country still needs to import rice despite being capable of producing it. One possible explanation is the decrease in normalized rice production, which means that the amount of rice produced per person is declining. This suggests a connection between population growth and rice production in the Philippines. As the population increases, the demand for rice also rises, creating more demands for the staple crop. However, the production of rice may not be keeping up with this increasing demand, leading to the need for imports to bridge the gap between supply and demand.
#
#
#
# <h3>Recommendations</h3>
# Based on the notable findings and conclusions, the following recommendations can be made:
# <ol>
#     <li><b>Enhance Rice Production Efficiency:</b> To address the decreasing trend in normalized rice production, efforts should be made to improve rice production efficiency. This could involve promoting modern agricultural techniques, providing farmers with access to advanced technologies, and supporting research and development initiatives in rice cultivation.</li>
#     <li><b>Invest in Climate-Resilient Farming Practices:</b> Given the higher mean temperature in the Philippines (until 2020) and the potential impacts of climate change, it is crucial to invest in climate-resilient farming practices. This may include promoting the cultivation of drought-tolerant rice varieties and implementing sustainable irrigation methods to cope with changing climatic conditions.</li>
#     <li><b>Optimize Water Resource Management:</b> With higher average annual rainfall in the Philippines compared to India, efficient water resource management is essential. Implementing effective irrigation systems, rainwater harvesting techniques, and water conservation practices can optimize water usage in agriculture and enhance overall productivity.</li>
#     <li><b>Promote Sustainable Land Use:</b>  While agricultural land in the Philippines is slightly increasing, it is important to prioritize sustainable land use practices. This can be achieved by promoting responsible land management, encouraging agroforestry practices that integrate trees and crops, and supporting reforestation efforts to combat deforestation and preserve natural resources.</li>
#     <li><b>Invest in Agricultural Research and Development:</b> To address the challenges and improve productivity, it is recommended to invest in agricultural research and development. This includes funding research on crop improvement, sustainable farming techniques, and innovative agricultural technologies to enhance productivity and sustainability in the sector.</li>
# </ol>
